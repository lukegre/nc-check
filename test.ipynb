# %%
import xarray as xr

# %%
ds = xr.open_dataset("/Users/luke/Downloads/GCB-2025_dataprod_CSIR-ML6_1982-2024.nc")

# %%
dir(ds.check)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_ds',
#  'all',
#  'cf',
#  'check_ocean_cover',
#  'check_time_cover',
#  'compliance',
#  'comply',
#  'full',
#  'make_cf_compliant',
#  'make_compliant',
#  'ocean_cover',
#  'time_cover']
